# %%
import pandas as pd
import numpy as np 
import os
import kagglehub
from IPython.display import Image # com essa biblioteca IPython conseguimos adicionar imagens :)
import matplotlib.pyplot as plt
import seaborn as sns

# Carregar o dataframe
df = pd.read_csv('olist_order_payments_dataset.csv')

# Exibir as primeiras linhas e informações básicas
print("Primeiras 5 linhas do DataFrame:")
print(df.head())
print("\nInformações básicas do DataFrame:")
df.info()
# Out:
# Primeiras 5 linhas do DataFrame:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45
#
# Informações básicas do DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
# ...

# %%
Image(filename=r'assets/infobasica.png')

# %%
Image(filename=r'assets/idvariaveis.png')

# %% [markdown]
# # 2. Estatísticas Descritivas 📝

# %%
print("\nEstatísticas Descritivas (df.describe()):")
print(df.describe())
Image(filename=r'assets/resumoestatico.png',width=800)
# Out:
# Estatísticas Descritivas (df.describe()):
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
Image(filename=r'assets/detalhespagamentos.png',width=800)

# %% [markdown]
# 3. Análise Visual Preliminar 📉

# %%
Image(filename=r'assets/observacao.png',width=900)

# %%
Image(filename=r'assets/payment_installments_boxplot.png',width=900)

# %%
Image(filename=r'assets/analisesimplesparcelaspagamentos.png')

# %%
# ==============================================================================
# AVISO: O bloco de código abaixo, referente ao cálculo de valores ausentes
# e à geração do heatmap, foi comentado intencionalmente.
# Os resultados (como a porcentagem de ausentes e a imagem 
# 'missing_values_heatmap.png') já foram gerados e salvos anteriormente.
# Descomente apenas se precisar executar esta análise novamente.
# ==============================================================================

# # Calcular a porcentagem de valores ausentes por coluna      
# missing_percentage = (df.isnull().sum() / len(df)) * 100
# print("\nPorcentagem de valores ausentes por coluna:")
# print(missing_percentage)

# # Gerar um heatmap com seaborn para visualização dos nulos
# plt.figure(figsize=(10, 6))
# sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
# plt.title('Heatmap de Valores Ausentes')
# plt.savefig('missing_values_heatmap.png')
# print("\nHeatmap de valores ausentes salvo como missing_values_heatmap.png")
# Out:
# Porcentagem de valores ausentes por coluna:
# order_id                0.0
# payment_sequential      0.0
# payment_type            0.0
# payment_installments    0.0
# payment_value           0.0
# dtype: float64
#
# Heatmap de valores ausentes salvo como missing_values_heatmap.png
